# %% [markdown]
# # skimage

# %%
from skimage.io import imread, imshow
# Out:
# c:\Users\benson_lee\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\benson_lee\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\benson_lee\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
img = imread('../data/blobs.tif')
img.dtype
# Out:
# dtype('uint8')

# %%
import matplotlib.pyplot as plt
plt.imshow(img, cmap = 'gray', interpolation= "none")

# %%
# trimming
cropped_img = img[0:128, 0:128]
plt.figure(figsize=(4,4))
plt.imshow(cropped_img, interpolation='none',cmap = 'gray')

# %%
img.shape

# %%
# Same concept to the numpy mask before: Thresholding
plt.figure(figsize=(4,4))
plt.imshow(img>100, interpolation='none',cmap = 'gray')
